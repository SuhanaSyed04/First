# %% [markdown]
# <a href="https://colab.research.google.com/github/SuhanaSyed04/First/blob/branch1/BoxPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
d=pd.read_csv('ds_salaries.csv')
# Creating dataset

 
fig = plt.figure(figsize =(10, 10))

plt.boxplot(d.salary_in_usd)
 
# show plot
plt.show()

# %% [markdown]
# # New Section
